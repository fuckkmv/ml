# %%
from sklearn.metrics import classification_report

# %%
### Q9 KNN for Classification 

from sklearn.neighbors import KNeighborsClassifier 
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris=load_iris()

X_train, X_test, Y_train, Y_test = train_test_split(iris.data,iris.target,test_size=0.3)

knn=KNeighborsClassifier(n_neighbors=3)

knn.fit(X_train,Y_train)

pred=knn.predict(X_test)

score=knn.score(X_test,Y_test)

print("score",score)

print(classification_report(Y_test, pred))
# Out:
# score 0.9777777777777777

# %%
### KNN for regression

from sklearn.neighbors import KNeighborsRegressor 
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris=load_iris()

X_train, X_test, Y_train, Y_test = train_test_split(iris.data,iris.target,test_size=0.3)

knn=KNeighborsRegressor(n_neighbors=5)

knn.fit(X_train,Y_train)

pred=knn.predict(X_test)

score=knn.score(X_test,Y_test)

print("score",score)
# Out:
# score 0.967616191904048

# %%
### Q10 Implement Decision Tree algorithm for classification problem using sklearn package.

from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris=load_iris()

X_train, X_test, Y_train, Y_test = train_test_split(iris.data,iris.target,test_size=0.3)

clf=DecisionTreeClassifier()

clf.fit(X_train,Y_train)

plot_tree(clf)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.75\ngini = 0.665\nsamples = 105\nvalue = [35, 32, 38]'),
#  Text(0.4, 0.75, 'gini = 0.0\nsamples = 35\nvalue = [35, 0, 0]'),
#  Text(0.6, 0.75, 'x[3] <= 1.75\ngini = 0.496\nsamples = 70\nvalue = [0, 32, 38]'),
#  Text(0.4, 0.5833333333333334, 'x[2] <= 5.35\ngini = 0.161\nsamples = 34\nvalue = [0, 31, 3]'),
#  Text(0.3, 0.4166666666666667, 'x[1] <= 2.25\ngini = 0.061\nsamples = 32\nvalue = [0, 31, 1]'),
#  Text(0.2, 0.25, 'x[2] <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.1, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.3, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.4, 0.25, 'gini = 0.0\nsamples = 30\nvalue = [0, 30, 0]'),
#  Text(0.5, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8, 0.5833333333333334, 'x[2] <= 4.85\ngini = 0.054\nsamples = 36\nvalue = [0, 1, 35]'),
# ...

# %%
### Q11 Implement Nave Bayes Classifier algorithm for classification problem using sklearn package

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

iris=load_iris()
X_train, X_test, Y_train, Y_test = train_test_split(iris.data,iris.target,test_size=0.3)

nb = GaussianNB()
nb.fit(X_train,Y_train)

pred=nb.predict(X_test)

accuracy = accuracy_score(Y_test, pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9555555555555556

# %%
### Q12 Implement SVM classifier for classification problem using sklearn package.

from sklearn.datasets import load_iris
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

iris = load_iris()

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3)

clf = SVC(kernel='linear')
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9333333333333333

# %%
### Q13 Implement Neural Network algorithm for classification problem using sklearn package.

from sklearn.datasets import load_iris
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

iris = load_iris()

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3)

clf = MLPClassifier(hidden_layer_sizes=(5,2), max_iter=1000)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6666666666666666
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
### Q14 Implement K-Means algorithms for clustering problem using sklearn package.

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

X, y = make_blobs(n_samples=500, centers=4, random_state=42)

kmeans = KMeans(n_clusters=4)
kmeans.fit(X)

labels = kmeans.labels_

centroids = kmeans.cluster_centers_

plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=200, alpha=0.5)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
